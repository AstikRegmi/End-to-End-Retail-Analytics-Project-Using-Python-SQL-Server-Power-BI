# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
df=pd.read_csv(r"C:\Users\Acer\Desktop\Data Analyst Projects\End to End Full Data Analyst Project\Data\customer_shopping_behavior.csv")

# %%
df.shape
# Out:
# (5050, 17)

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  5050.000000  5050.000000            4494.000000    4449.000000
# mean   2519.570891    44.150495             144.765236       3.668195
# std    1470.402964    15.282328             275.590101       0.865357
# min       1.000000    18.000000              10.120000       1.000000
# 25%    1252.250000    31.000000              41.000000       3.000000
# 50%    2499.500000    44.000000              65.000000       3.700000
# 75%    3740.750000    57.000000              89.000000       4.400000
# max    5099.000000    70.000000            1499.760000       5.000000
#
#        Previous Purchases
# count         4502.000000
# mean            25.221901
# std             14.521635
# min              0.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.describe(include='object')
# Out:
#        Gender Item Purchased  Category  Location  Size  Color  Season  \
# count    5050           5050      5050      5050  4680   5050    5050
# unique      3             30         5        54     4     25       5
# top      Male          Shirt  Clothing  New York     M  Black  Spring
# freq     3018            320      2130       337  1981    404    1280
#
#        Subscription Status Shipping Type Discount Applied Payment Method  \
# count                 5050          5050             5050           5050
# unique                   2             6                2              6
# top                     No      Standard               No    Credit Card
# freq                  3462          1213             2789            954
#
#        Frequency of Purchases
# count                    5050
# unique                      7
# top                   Monthly
# freq                      946

# %%
df.describe(include='all')
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   5050.000000  5050.000000   5050           5050      5050
# unique          NaN          NaN      3             30         5
# top             NaN          NaN   Male          Shirt  Clothing
# freq            NaN          NaN   3018            320      2130
# mean    2519.570891    44.150495    NaN            NaN       NaN
# std     1470.402964    15.282328    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%     1252.250000    31.000000    NaN            NaN       NaN
# 50%     2499.500000    44.000000    NaN            NaN       NaN
# 75%     3740.750000    57.000000    NaN            NaN       NaN
# max     5099.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD)  Location  Size  Color  Season  Review Rating  \
# count             4494.000000      5050  4680   5050    5050    4449.000000
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                      370
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# ...

# %%
df['Item Purchased'].unique()
# Out:
# array(['T-shirt', 'Sunglasses', 'Shirt', 'Gloves', 'Jewelry', 'Shorts',
#        'Hat', 'Handbag', 'Shoes', 'Coat', 'Laptop', 'Hoodie', 'Phone',
#        'Jacket', 'Pants', 'Backpack', 'Socks', 'Jeans', 'Bag', 'Belt',
#        'Watch', 'Headphones', 'Blouse', 'Sandals', 'Skirt', 'Sweater',
#        'Scarf', 'Sneakers', 'Boots', 'Dress'], dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Clothing', 'Accessories', 'Outerwear', 'Electronics', 'Footwear'],
#       dtype=object)

# %%
pd.set_option('display.max_colwidth',None)
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories               [Sunglasses, Gloves, Jewelry, Hat, Handbag, Phone, Backpack, Belt, Bag, Headphones, Scarf, Watch, Shirt, Shoes, Laptop]
# Clothing       [T-shirt, Shirt, Shorts, Shoes, Hoodie, Phone, Pants, Socks, Jeans, Bag, Blouse, Skirt, Sweater, Watch, Laptop, Dress, Headphones]
# Electronics                                                                                 [Laptop, Phone, Watch, Bag, Shoes, Shirt, Headphones]
# Footwear                                                                                                        [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                                                                                                          [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
df.groupby('Category') ['Season'].max()
# Out:
# Category
# Accessories    Winter
# Clothing       Winter
# Electronics    Winter
# Footwear       Winter
# Outerwear      Winter
# Name: Season, dtype: object

# %% [markdown]
# ## Product Category and Item Mapping

# %%
correct_mapping = {
    'Sunglasses': 'Accessories',
    'Gloves': 'Accessories',
    'Jewelry': 'Accessories',
    'Hat': 'Accessories',
    'Handbag': 'Accessories',
    'Belt': 'Accessories',
    'Backpack': 'Accessories',
    'Scarf': 'Accessories',

    'T-shirt': 'Clothing',
    'Shirt': 'Clothing',
    'Shorts': 'Clothing',
    'Hoodie': 'Clothing',
    'Pants': 'Clothing',
    'Socks': 'Clothing',
    'Jeans': 'Clothing',
    'Blouse': 'Clothing',
    'Skirt': 'Clothing',
    'Sweater': 'Clothing',
    'Dress': 'Clothing',

    'Laptop': 'Electronics',
    'Phone': 'Electronics',
    'Watch': 'Electronics',
    'Headphones': 'Electronics',

    'Shoes': 'Footwear',
    'Sandals': 'Footwear',
    'Sneakers': 'Footwear',
    'Boots': 'Footwear',

    'Coat': 'Outerwear',
    'Jacket': 'Outerwear',

    'Bag': 'Accessories'
}

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# ...

# %%
df['Category']=df['Item Purchased'].map(correct_mapping)

# %%
df.groupby('Category') ['Item Purchased'].unique()
# Out:
# Category
# Accessories                 [Sunglasses, Gloves, Jewelry, Hat, Handbag, Backpack, Bag, Belt, Scarf]
# Clothing       [T-shirt, Shirt, Shorts, Hoodie, Pants, Socks, Jeans, Blouse, Skirt, Sweater, Dress]
# Electronics                                                      [Laptop, Phone, Watch, Headphones]
# Footwear                                                          [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                                                            [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %% [markdown]
# ## Treating Null Values

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                      370
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df['Size'].unique()
# Out:
# array(['XL', 'M', 'L', 'S', nan], dtype=object)

# %%
df.groupby('Category') ['Size'].unique()
# Out:
# Category
# Accessories    [M, L, S, XL, nan]
# Clothing       [XL, M, S, L, nan]
# Electronics    [nan, L, S, M, XL]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
df.loc[df['Category']=='Electronics','Size']='Not Applicable'

# %%
df.loc[df['Category']=='Accessories','Size']='Free Size'

# %%
df.loc[df['Category']=='Footwear','Size']='Not Available'

# SInce hsows size is in numbers not l, xl

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                       51
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %%
df.groupby('Category') ['Size'].unique()
# Out:
# Category
# Accessories           [Free Size]
# Clothing       [XL, M, S, L, nan]
# Electronics      [Not Applicable]
# Footwear          [Not Available]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
df[df['Category']=='Clothing']['Size'].value_counts()
# Out:
# Size
# M     813
# L     517
# S     318
# XL    205
# Name: count, dtype: int64

# %%
df[df['Category']=='Clothing']['Size'].isnull().sum()
# Out:
# np.int64(51)

# %%
813+51
# Out:
# 864

# %%
df.loc[
    (df['Category']=='Clothing') & (df['Size'].isna()),
    'Size'
] = df.loc[df['Category']=='Clothing', 'Size'].mode()[0]

# %%
df[df['Category']=='Clothing']['Size'].value_counts()
# Out:
# Size
# M     864
# L     517
# S     318
# XL    205
# Name: count, dtype: int64

# %% [markdown]
# ## Review Rating

# %%
df['Review Rating'].mean()
# Out:
# np.float64(3.668195100022477)

# %%
df['Review Rating'].median()
# Out:
# 3.7

# %%
df['Review Rating'] = df['Review Rating'].fillna(
    df.groupby('Item Purchased')['Review Rating'].transform('mean')
)


# transform is like window function, it dont collapse rows.
# since this logic is based on indexing, so equal shape is needed in both LHS and RHS

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %%
df['Review Rating']=df['Review Rating'].round(2)

# %% [markdown]
# ## Previous Purchase

# %%
df['Previous Purchases']=df['Previous Purchases'].fillna('0')

# %% [markdown]
# ## Purchase Amt

# %%
df['Purchase Amount (USD)'] = df['Purchase Amount (USD)'].fillna(
    df.groupby('Item Purchased')['Purchase Amount (USD)'].transform('mean')
)

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %% [markdown]
# # Checking Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(50)

# %%
df.shape
# Out:
# (5050, 17)

# %%
df=df.drop_duplicates(subset=['Customer ID'], keep='first')

# %%
df.shape
# Out:
# (5000, 17)

# %% [markdown]
# # Renaming Headers

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Previous Purchases', 'Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.columns=df.columns.str.replace(" ","_")
df.columns=df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %%
df.rename(columns={'purchase_amount_(usd)':'purchase_amount'},inplace=True)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %% [markdown]
# # Connection to SSMS

# %%
# !pip install pymysql sqlalchemy

# %%
from sqlalchemy import create_engine
import urllib

# %%
server=r"DESKTOP-5BVB5CF\MSSQLSERVER01"
database='retails'
driver="ODBC Driver 17 for SQL Server"


engine = create_engine(
    f"mssql+pyodbc://@{server}/{database}?driver={driver.replace(' ', '+')}&trusted_connection=yes"
)

# %%
df.to_sql(
    "retail_cleaned",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 80

# %%
df.shape
# Out:
# (5000, 17)
